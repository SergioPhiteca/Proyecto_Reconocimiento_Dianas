# %%
#Creamos las carpetas deseadas.
# !mkdir Dianas
# !mkdir no_Dianas
# !mkdir TEST

# %%
#mostramos el contenido de las carpetas.
# !ls /content/Dianas | wc -l
# !ls /content/no_Dianas | wc -l
# !ls /content/TEST | wc -l
# Out:
# 100
# 100
# 199

# %%
#mostramos mas imagenes
import os
import matplotlib.pyplot as plt
import matplotlib.image as mping

plt.figure(figsize=(15,15))

carpeta = '/content/Dianas'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
    plt.subplot(5,5,i+1)
    imagen = mping.imread(carpeta + '/' + nombreimg)
    plt.imshow(imagen)

# %%
#crear carpetas para hacer el set de datos.
# !mkdir dataset
# !mkdir dataset/Diana
# !mkdir dataset/no_Dianas

# %%
import shutil
import os

# Especifica las rutas de las carpetas de origen y destino
ruta_origen = '/content/Dianas'
ruta_destino = '/content/dataset/Diana'

# Obtener una lista de todos los archivos en la carpeta de origen
archivos = os.listdir(ruta_origen)

# Copiar cada archivo a la carpeta de destino sin eliminarlos de la carpeta de origen
for archivo in archivos:
    shutil.copy(os.path.join(ruta_origen, archivo), ruta_destino)

# %%
import shutil
import os

# Especifica las rutas de las carpetas de origen y destino
ruta_origen = '/content/no_Dianas'
ruta_destino = '/content/dataset/no_Dianas'

# Obtener una lista de todos los archivos en la carpeta de origen
archivos = os.listdir(ruta_origen)

# Copiar cada archivo a la carpeta de destino sin eliminarlos de la carpeta de origen
for archivo in archivos:
    shutil.copy(os.path.join(ruta_origen, archivo), ruta_destino)

# %%
#mostramos el contenido de las carpetas.
# !ls /content/dataset/Diana| wc -l
# !ls /content/dataset/no_Dianas| wc -l
# Out:
# 100
# 100

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Crear el generador de imágenes sin transformaciones
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Crear el generador de entrenamiento
data_gen_entrenamiento = datagen.flow_from_directory(
    '/content/dataset',
    target_size=(224, 224),
    batch_size=32,
    shuffle=True,
    subset='training'
)

# Crear el generador de validación
data_gen_validacion = datagen.flow_from_directory(
    '/content/dataset',
    target_size=(224, 224),
    batch_size=32,
    shuffle=True,
    subset='validation'
)

def mostrar_ejemplos(data_gen, num_ejemplos=8):
    imagenes, _ = next(data_gen)
    fig, axs = plt.subplots(1, num_ejemplos, figsize=(15, 15))
    for i in range(num_ejemplos):
        axs[i].imshow(imagenes[i])
        axs[i].axis('off')
    plt.show()

# Mostrar ejemplos del conjunto de entrenamiento
mostrar_ejemplos(data_gen_entrenamiento)

# Mostrar ejemplos del conjunto de validación
mostrar_ejemplos(data_gen_validacion)
# Out:
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
# Obtener el número total de muestras de entrenamiento y validación
total_entrenamiento = data_gen_entrenamiento.samples
total_validacion = data_gen_validacion.samples

# Calcular el porcentaje correspondiente
porcentaje_entrenamiento = total_entrenamiento / (total_entrenamiento + total_validacion) * 100
porcentaje_validacion = total_validacion / (total_entrenamiento + total_validacion) * 100

# Crear un gráfico de barras con los porcentajes
plt.bar(['Entrenamiento', 'Validación'], [porcentaje_entrenamiento, porcentaje_validacion])
plt.title('Porcentaje de muestras de entrenamiento y validación')
plt.xlabel('Conjunto de datos')
plt.ylabel('Porcentaje')
plt.show()

# %%
print(data_gen_validacion.class_indices)
# Out:
# {'Diana': 0, 'no_Dianas': 1}

# %%
indices_de_clase = data_gen_validacion.class_indices

# %%
#modelo preentrenado.
import tensorflow as tf
import tensorflow_hub as hub

url = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

# %%
modelo = tf.keras.Sequential([
   mobilenetv2,
   tf.keras.layers.Dense(2, activation = 'softmax') 
])

# Compilar y resumir el modelo
modelo.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
modelo.summary()

# import tensorflow as tf
# from tensorflow.keras.applications import MobileNetV2

# # Cargar el modelo MobileNetV2 pre-entrenado
# mobilenetv2 = MobileNetV2(include_top=False, weights='imagenet', input_shape=(224, 224, 3))

# # Crear el modelo Sequential y agregar las capas
# modelo = tf.keras.Sequential([
#     tf.keras.layers.Input(shape=(224, 224, 4)),  # Especifica la forma de entrada esperada
#     tf.keras.layers.Lambda(lambda x: x[..., :3]),  # Descarta el cuarto canal
#     mobilenetv2,
#     tf.keras.layers.Flatten(),  # Aplanar las salidas del MobileNetV2
#     tf.keras.layers.Dense(2, activation='softmax')
# ])

# # Compilar y resumir el modelo
# modelo.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 2)                 2562
#
# =================================================================
# Total params: 2,260,546
# Trainable params: 2,562
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
#entrenar el modelo.
EPOCAS=50

historial = modelo.fit(
    data_gen_entrenamiento, epochs=50, batch_size=32,
    validation_data=data_gen_validacion
)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 16s 463ms/step - loss: 0.5405 - accuracy: 0.6875 - val_loss: 0.2149 - val_accuracy: 0.9500
# Epoch 2/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0938 - accuracy: 0.9875 - val_loss: 0.0698 - val_accuracy: 1.0000
# Epoch 3/50
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 4/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 5/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 6/50
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 7/50
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 8/50
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 9/50
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 10/50
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 12/50
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 13/50
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 14/50
# 5/5 [==============================] - 2s 558ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 20/50
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 1s 297ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 1s 294ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 1s 204ms/step - loss: 9.9173e-04 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 1s 205ms/step - loss: 9.6549e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 1s 200ms/step - loss: 9.3822e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 1s 196ms/step - loss: 9.0894e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 1s 203ms/step - loss: 8.8706e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 1s 206ms/step - loss: 8.6217e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 1s 306ms/step - loss: 8.4058e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 1s 275ms/step - loss: 8.1930e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 1s 198ms/step - loss: 7.9685e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 1s 208ms/step - loss: 7.7607e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 1s 203ms/step - loss: 7.5794e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 1s 199ms/step - loss: 7.3812e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 1s 209ms/step - loss: 7.1993e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 1s 206ms/step - loss: 7.0310e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 1s 207ms/step - loss: 6.8796e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 1s 198ms/step - loss: 6.7174e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 1s 224ms/step - loss: 6.5465e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 2s 346ms/step - loss: 6.4057e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 1s 249ms/step - loss: 6.2531e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 1s 220ms/step - loss: 6.1308e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 1s 198ms/step - loss: 5.9908e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 1s 204ms/step - loss: 5.8615e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000

# %%
#grafica de acc.
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(50)

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Validacion')
plt.legend(loc='lower right')
plt.title('Precision de entrenamiento y validacion')
plt.xlabel('épocas')
plt.ylabel('%', rotation=0)

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_loss, label='Precisión Validacion')
plt.legend(loc='upper right')
plt.title('Perdida de entrenamiento y validacion')
plt.xlabel('épocas')
plt.ylabel('%', rotation=0)

plt.suptitle('Gráfica de entrenamiento y validación', fontsize=20, fontweight='bold', y=0.959)
plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# # **1. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Test 1')
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Solicitar al usuario que seleccione un número de imagen
    num_imagen = int(input('Por favor, seleccione un número de imagen: '))

    # Comprobar si el número de imagen es válido
    if num_imagen < 0 or num_imagen >= len(lista_imagenes):
        print('Número de imagen inválido. Saliendo...')
    else:
        # Seleccionar la imagen correspondiente al número seleccionado
        imagen_seleccionada = lista_imagenes[num_imagen]
        ruta_imagen_seleccionada = os.path.join(ruta_carpeta, imagen_seleccionada)

        # Cargar la imagen seleccionada y mostrarla
        img = Image.open(ruta_imagen_seleccionada)
        img = img.rotate(0, expand=True)
        img = img.resize((160, 160))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Preprocesar la imagen seleccionada
        img_copy = img.copy()
        img_copy = img_copy.resize((224, 224))
        x = np.array(img_copy).astype(float)/255
        x = np.expand_dims(x, axis=0)

        # Realizar la predicción y mostrar los resultados
        prediccion = modelo.predict(x)
        for i in range(len(prediccion[0])):
            print(f"Clase {i}: {prediccion[0][i]:.3f}")
        nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen_seleccionada, indices_de_clase)
        print(f"La clase predicha es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")

# %% [markdown]
# # **2. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Test 2')
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Solicitar al usuario que seleccione un número de imagen
    num_imagen = int(input('Por favor, seleccione un número de imagen: '))

    # Comprobar si el número de imagen es válido
    if num_imagen < 0 or num_imagen >= len(lista_imagenes):
        print('Número de imagen inválido. Saliendo...')
    else:
        # Seleccionar la imagen correspondiente al número seleccionado
        imagen_seleccionada = lista_imagenes[num_imagen]
        ruta_imagen_seleccionada = os.path.join(ruta_carpeta, imagen_seleccionada)

        # Cargar la imagen seleccionada y mostrarla
        img = Image.open(ruta_imagen_seleccionada)
        img = img.rotate(0, expand=True)
        img = img.resize((160, 160))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Preprocesar la imagen seleccionada
        img_copy = img.copy()
        img_copy = img_copy.resize((224, 224))
        x = np.array(img_copy).astype(float)/255
        x = np.expand_dims(x, axis=0)

        # Realizar la predicción y mostrar los resultados
        prediccion = modelo.predict(x)
        for i in range(len(prediccion[0])):
            print(f"Clase {i}: {prediccion[0][i]:.3f}")
        nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen_seleccionada, indices_de_clase)
        print(f"La clase predicha es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")

# %% [markdown]
# # **3. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Test 3')
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Solicitar al usuario que seleccione un número de imagen
    num_imagen = int(input('Por favor, seleccione un número de imagen: '))

    # Comprobar si el número de imagen es válido
    if num_imagen < 0 or num_imagen >= len(lista_imagenes):
        print('Número de imagen inválido. Saliendo...')
    else:
        # Seleccionar la imagen correspondiente al número seleccionado
        imagen_seleccionada = lista_imagenes[num_imagen]
        ruta_imagen_seleccionada = os.path.join(ruta_carpeta, imagen_seleccionada)

        # Cargar la imagen seleccionada y mostrarla
        img = Image.open(ruta_imagen_seleccionada)
        img = img.rotate(0, expand=True)
        img = img.resize((160, 160))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Preprocesar la imagen seleccionada
        img_copy = img.copy()
        img_copy = img_copy.resize((224, 224))
        x = np.array(img_copy).astype(float)/255
        x = np.expand_dims(x, axis=0)

        # Realizar la predicción y mostrar los resultados
        prediccion = modelo.predict(x)
        for i in range(len(prediccion[0])):
            print(f"Clase {i}: {prediccion[0][i]:.3f}")
        nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen_seleccionada, indices_de_clase)
        print(f"La clase predicha es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")

# %% [markdown]
# # **4. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Test 4')
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Solicitar al usuario que seleccione un número de imagen
    num_imagen = int(input('Por favor, seleccione un número de imagen: '))

    # Comprobar si el número de imagen es válido
    if num_imagen < 0 or num_imagen >= len(lista_imagenes):
        print('Número de imagen inválido. Saliendo...')
    else:
        # Seleccionar la imagen correspondiente al número seleccionado
        imagen_seleccionada = lista_imagenes[num_imagen]
        ruta_imagen_seleccionada = os.path.join(ruta_carpeta, imagen_seleccionada)

        # Cargar la imagen seleccionada y mostrarla
        img = Image.open(ruta_imagen_seleccionada)
        img = img.rotate(0, expand=True)
        img = img.resize((160, 160))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Preprocesar la imagen seleccionada
        img_copy = img.copy()
        img_copy = img_copy.resize((224, 224))
        x = np.array(img_copy).astype(float)/255
        x = np.expand_dims(x, axis=0)

        # Realizar la predicción y mostrar los resultados
        prediccion = modelo.predict(x)
        for i in range(len(prediccion[0])):
            print(f"Clase {i}: {prediccion[0][i]:.3f}")
        nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen_seleccionada, indices_de_clase)
        print(f"La clase predicha es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")

# %% [markdown]
# # **5. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Test 5')
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Solicitar al usuario que seleccione un número de imagen
    num_imagen = int(input('Por favor, seleccione un número de imagen: '))

    # Comprobar si el número de imagen es válido
    if num_imagen < 0 or num_imagen >= len(lista_imagenes):
        print('Número de imagen inválido. Saliendo...')
    else:
        # Seleccionar la imagen correspondiente al número seleccionado
        imagen_seleccionada = lista_imagenes[num_imagen]
        ruta_imagen_seleccionada = os.path.join(ruta_carpeta, imagen_seleccionada)

        # Cargar la imagen seleccionada y mostrarla
        img = Image.open(ruta_imagen_seleccionada)
        img = img.rotate(0, expand=True)
        img = img.resize((160, 160))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Preprocesar la imagen seleccionada
        img_copy = img.copy()
        img_copy = img_copy.resize((224, 224))
        x = np.array(img_copy).astype(float)/255
        x = np.expand_dims(x, axis=0)

        # Realizar la predicción y mostrar los resultados
        prediccion = modelo.predict(x)
        for i in range(len(prediccion[0])):
            print(f"Clase {i}: {prediccion[0][i]:.3f}")
        nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen_seleccionada, indices_de_clase)
        print(f"La clase predicha es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")

# %% [markdown]
# # **6. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Test 6')
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Solicitar al usuario que seleccione un número de imagen
    num_imagen = int(input('Por favor, seleccione un número de imagen: '))

    # Comprobar si el número de imagen es válido
    if num_imagen < 0 or num_imagen >= len(lista_imagenes):
        print('Número de imagen inválido. Saliendo...')
    else:
        # Seleccionar la imagen correspondiente al número seleccionado
        imagen_seleccionada = lista_imagenes[num_imagen]
        ruta_imagen_seleccionada = os.path.join(ruta_carpeta, imagen_seleccionada)

        # Cargar la imagen seleccionada y mostrarla
        img = Image.open(ruta_imagen_seleccionada)
        img = img.rotate(0, expand=True)
        img = img.resize((160, 160))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Preprocesar la imagen seleccionada
        img_copy = img.copy()
        img_copy = img_copy.resize((224, 224))
        x = np.array(img_copy).astype(float)/255
        x = np.expand_dims(x, axis=0)

        # Realizar la predicción y mostrar los resultados
        prediccion = modelo.predict(x)
        for i in range(len(prediccion[0])):
            print(f"Clase {i}: {prediccion[0][i]:.3f}")
        nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen_seleccionada, indices_de_clase)
        print(f"La clase predicha es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")

# %% [markdown]
# # **7. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Test 7')
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Solicitar al usuario que seleccione un número de imagen
    num_imagen = int(input('Por favor, seleccione un número de imagen: '))

    # Comprobar si el número de imagen es válido
    if num_imagen < 0 or num_imagen >= len(lista_imagenes):
        print('Número de imagen inválido. Saliendo...')
    else:
        # Seleccionar la imagen correspondiente al número seleccionado
        imagen_seleccionada = lista_imagenes[num_imagen]
        ruta_imagen_seleccionada = os.path.join(ruta_carpeta, imagen_seleccionada)

        # Cargar la imagen seleccionada y mostrarla
        img = Image.open(ruta_imagen_seleccionada)
        img = img.rotate(0, expand=True)
        img = img.resize((160, 160))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Preprocesar la imagen seleccionada
        img_copy = img.copy()
        img_copy = img_copy.resize((224, 224))
        x = np.array(img_copy).astype(float)/255
        x = np.expand_dims(x, axis=0)

        # Realizar la predicción y mostrar los resultados
        prediccion = modelo.predict(x)
        for i in range(len(prediccion[0])):
            print(f"Clase {i}: {prediccion[0][i]:.3f}")
        nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen_seleccionada, indices_de_clase)
        print(f"La clase predicha es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")

# %% [markdown]
# # **8. Test**

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision

# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Procesar cada imagen de la lista
    for imagen in lista_imagenes:
        if imagen.endswith('.jpg') or imagen.endswith('.png') or imagen.endswith('.jpeg'):
            ruta_imagen = os.path.join(ruta_carpeta, imagen)

            # Cargar la imagen y mostrarla
            img = Image.open(ruta_imagen)
            img = img.rotate(0, expand=True)
            # img = img.resize((160, 160))
            plt.imshow(img)
            plt.axis('off')
            plt.show()

            # Preprocesar la imagen
            img_copy = img.copy()
            img_copy = img_copy.resize((224, 224))
            x = np.array(img_copy).astype(float)/255
            x = np.expand_dims(x, axis=0)

            # Realizar la predicción y mostrar los resultados
            prediccion = modelo.predict(x)
            for i in range(len(prediccion[0])):
                print(f"Clase {i}: {prediccion[0][i]:.3f}")
            nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen, indices_de_clase)
            print(f"La clase predicha para la imagen {imagen} es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")
        else:
            print(f"La imagen {imagen} no es un archivo de imagen válido y se omitirá.")

# %% [markdown]
# # **Test**

# %%
import cv2
import os

# Ruta al directorio que contiene las imágenes
directorio_imagenes = '/content/TEST'

# Recorre todas las imágenes en el directorio
for nombre_archivo in os.listdir(directorio_imagenes):
    # Lee la imagen
    ruta_imagen = os.path.join(directorio_imagenes, nombre_archivo)
    imagen = cv2.imread(ruta_imagen, cv2.IMREAD_UNCHANGED)
    
    # Verifica si la imagen no es 'None' y tiene 4 canales
    if imagen is not None and imagen.shape[2] == 4:
        # Elimina el cuarto canal
        imagen = imagen[:, :, :3]
        
        # Guarda la imagen modificada
        cv2.imwrite(ruta_imagen, imagen)

# %%
import os
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np
import pandas as pd

# Crear una lista vacía para almacenar los resultados
resultados_list = []

def categorizar(ruta_local, class_indices):
    # Cargar la imagen desde el conjunto de datos local
    img = Image.open(ruta_local)
    img = np.array(img).astype(float)/255

    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1,224,224,3))

    # Obtener la etiqueta de clase predicha y su precisión
    etiqueta_de_clase_predicha = np.argmax(prediccion[0], axis=-1)
    precision = round(prediccion[0][etiqueta_de_clase_predicha], 3)

    # Asignar la etiqueta de clase predicha a su nombre de clase correspondiente
    nombre_de_clase_predicho = list(class_indices.keys())[list(class_indices.values()).index(etiqueta_de_clase_predicha)]

    # Devolver el resultado
    return nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision
    
# Solicitar al usuario que ingrese la ruta de la carpeta que contiene las imágenes
ruta_carpeta = '/content/TEST'

# Comprobar si la ruta es válida
if not os.path.isdir(ruta_carpeta):
    print('La ruta especificada no es válida. Saliendo...')
else:
    # Obtener la lista de imágenes en la carpeta y ordenarla en orden ascendente
    lista_imagenes = sorted(os.listdir(ruta_carpeta))

    # Mostrar la lista de imágenes disponibles
    print('Las imágenes disponibles son:')
    for i, imagen in enumerate(lista_imagenes):
        print(f'{i}: {imagen}')

    # Procesar cada imagen de la lista
    for imagen in lista_imagenes:
        if imagen.endswith('.jpg') or imagen.endswith('.png') or imagen.endswith('.jpeg'):
            ruta_imagen = os.path.join(ruta_carpeta, imagen)

            # Cargar la imagen y mostrarla
            img = Image.open(ruta_imagen)
            img = img.rotate(0, expand=True)
            # img = img.resize((160, 160))
            plt.imshow(img)
            plt.axis('off')
            plt.show()

            # Preprocesar la imagen
            img_copy = img.copy()
            img_copy = img_copy.resize((224, 224))
            x = np.array(img_copy).astype(float)/255
            x = np.expand_dims(x, axis=0)

            # Realizar la predicción y mostrar los resultados
            prediccion = modelo.predict(x)
            for i in range(len(prediccion[0])):
                print(f"Clase {i}: {prediccion[0][i]:.3f}")
            nombre_de_clase_predicho, etiqueta_de_clase_predicha, precision = categorizar(ruta_imagen, indices_de_clase)
            print(f"La clase predicha para la imagen {imagen} es {nombre_de_clase_predicho} (número {etiqueta_de_clase_predicha}) con una precisión de {precision:.3f}.")
            
            # Agregar los resultados a la lista de resultados
            resultados_list.append({'Nombre_archivo': imagen, 
                                    'Prediccion': nombre_de_clase_predicho, 
                                    'Prediccion_diana': f"{prediccion[0][0] * 100:.2f}%",    
                                    'Prediccion_no_diana': f"{prediccion[0][1] * 100:.2f}%",
                                    'Precision_val': f"{precision * 100:.2f}%"})

        else:
            print(f"La imagen {imagen} no es un archivo de imagen válido y se omitirá.")

# Crear un DataFrame de pandas a partir de la lista de resultados y guardar los resultados en un archivo CSV
resultados = pd.DataFrame(resultados_list)
resultados.to_csv('resultados.csv', index=False)
